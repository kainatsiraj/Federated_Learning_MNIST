# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
# !git config --global user.email "kainatsiraj0@gmail.com"
# !git config --global user.name "kainatsiraj"

# %%
# !git init
# !git remote add origin https://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@github.com/kainatsiraj/Federated_Learning_MNIST.git
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/
# error: remote origin already exists.

# %%
# !git add .
# !git commit -m "first commit"
# !git branch -M main
# !git push -u origin main
# Out:
# [main b3b10ed] first commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
# To https://github.com/kainatsiraj/Federated_Learning_MNIST.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/kainatsiraj/Federated_Learning_MNIST.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
git pull origin main --rebase
# Out:
#   File "/tmp/ipykernel_21279/3980290468.py", line 1
#     git pull origin main --rebase
#         ^
# SyntaxError: invalid syntax
