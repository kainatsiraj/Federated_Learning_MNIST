# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive')
# !ls
# Out:
# '0051e5e8-d1c4-4a84-bf3a-a426cdad6285___RS_LB 4640.JPG'
# '00695906-210d-4a9d-822e-986a17384115___RS_LB 4026.JPG'
# '006cc01a-1888-4326-9b62-a65cb55a6377___RS_LB 5207.JPG'
# '0085ef03-aec3-431a-99a1-de286e10c0cf___RS_LB 2949.JPG'
# '00b1f292-23dd-44d4-aad3-c1ffb6a6ad5a___RS_LB 4479.JPG'
# '0114b195-844c-4978-93a9-b0d5aae010f1___RS_LB 2738.JPG'
# '01270f5c-a44b-4da7-9398-289088c197ab___RS_LB 2517.JPG'
# '01a8cc9f-074a-4866-87c8-bb5a9e3895b4___RS_LB 2968.JPG'
# '01ad74ce-eb28-42c7-9204-778d17cfd45c___RS_LB 2669.JPG'
# '0201bf8e-27e3-4c92-ae97-2fb4f665b5d3___RS_LB 4320.JPG'
# '02212653-e92b-49aa-96b7-9497af51e502___RS_LB 3151.JPG'
# '02282fee-ba3f-460e-91e0-630204ab96c2___RS_LB 5031.JPG'
# '025f3c76-6d6c-4dad-ba22-e3e72d084ef1___RS_LB 3105.JPG'
# '02c8ff21-4e0a-4326-ba8f-089e5cb45b74___RS_LB 4089.JPG'
# '030e8945-d3ce-4ad3-8a91-a14c18285249___RS_LB 2532.JPG'
# '031672c9-bf0a-46bf-8b52-d7cdc067612e___RS_LB 5019.JPG'
# '031c39d3-9a91-4e81-85ac-b36512133b0a___RS_LB 5220.JPG'
# ...

# %%
# !git config --global user.email "kainatsiraj0@gmail.com"
# !git config --global user.name "kaiatsiraj"

# %%
# !git remote remove origin
# !git remote add origin https://ghp_GhGUw2ftNZ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dqLXmqSpgyRjjAMEtCg22ppDpR@github.com/kainatsiraj/Federated_Learning_MNIST.git

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 3.12 KiB | 24.00 KiB/s, done.
# From https://github.com/kainatsiraj/Federated_Learning_MNIST
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')
# !ls
# Out:
# 'CIFAR-10 SIMPLE IMAGE CLASSIFICATION.ipynb'
# 'Copy of CIFAR-10 SIMPLE IMAGE CLASSIFICATION'
# 'Copy of potato disease classification with CNN'
# 'Copy of Untitled0.ipynb'
# 'Copy of Untitled1.ipynb'
# 'Copy of Untitled2.ipynb'
# 'Copy of Welcome to Colab'
# 'Copy of Welcome to Colab (1)'
#  Federated_Learning_MNIST.ipynb
# 'potato disease classification with CNN.ipynb'
# 'REGRESSION CNN ON HOUSING DATA'
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb

# %%
# !rm -rf .git
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
# !git remote add origin https://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@github.com/kainatsiraj/Federated_Learning_MNIST.git

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 3.12 KiB | 22.00 KiB/s, done.
# From https://github.com/kainatsiraj/Federated_Learning_MNIST
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
# !git add .
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   CIFAR-10 SIMPLE IMAGE CLASSIFICATION.ipynb
# 	new file:   Copy of CIFAR-10 SIMPLE IMAGE CLASSIFICATION
# 	new file:   Copy of Untitled0.ipynb
# 	new file:   Copy of Untitled1.ipynb
# 	new file:   Copy of Untitled2.ipynb
# 	new file:   Copy of Welcome to Colab
# 	new file:   Copy of Welcome to Colab (1)
# 	new file:   Copy of potato disease classification with CNN
# 	new file:   Federated_Learning_MNIST.ipynb
# 	new file:   REGRESSION CNN ON HOUSING DATA
# 	new file:   Untitled0.ipynb
# 	new file:   Untitled1.ipynb
# 	new file:   Untitled3.ipynb
# 	new file:   Untitled4.ipynb
# 	new file:   potato disease classification with CNN.ipynb

# %%
# !git commit -m "first commit - Federated_Learning_MNIST"
# !git branch -M main
# !git push origin main
# Out:
# [master 78d621e] first commit - Federated_Learning_MNIST
#  15 files changed, 15 insertions(+)
#  create mode 100644 CIFAR-10 SIMPLE IMAGE CLASSIFICATION.ipynb
#  create mode 100644 Copy of CIFAR-10 SIMPLE IMAGE CLASSIFICATION
#  create mode 100644 Copy of Untitled0.ipynb
#  create mode 100644 Copy of Untitled1.ipynb
#  create mode 100644 Copy of Untitled2.ipynb
#  create mode 100644 Copy of Welcome to Colab
#  create mode 100644 Copy of Welcome to Colab (1)
#  create mode 100644 Copy of potato disease classification with CNN
#  create mode 100644 Federated_Learning_MNIST.ipynb
#  create mode 100644 REGRESSION CNN ON HOUSING DATA
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 Untitled3.ipynb
#  create mode 100644 Untitled4.ipynb
#  create mode 100644 potato disease classification with CNN.ipynb
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 2 threads
# ...
